# %% [markdown]
# ### AI refers to computer systems that can handle tasks that usually need human intelligence—like reasoning, learning from data, understanding language, and making informed decisions.
#
# This definition captures the essence of AI: systems that perform intelligent tasks without needing to mimic human feelings. It covers everything from reasoning to decision-making.

# %% [markdown]
# # Classify each technology as either AI or Not AI.
#
# ### AI
#
# A warehouse robot that navigates around
# obstacles and optimizes its route based on real-time
# conditions
# 📤
# A spam filter that learns which emails you mark
# as junk and improves its detection over time
# 💬
# A customer service chatbot that understands
# natural language questions and provides relevant
# answers
#
# ### NOT AI
#
# �
# A printer that pauses when it runs out of paper
# 🔢
# A spreadsheet that automatically calculates
# totals using formulas you've entered
# ☕
# A coffee machine that starts brewing when you
# press a button
#
# AI systems learn, adapt, and make intelligent decisions, while traditional software follows fixed rules without learning or reasoning capabilities.

# %% [markdown]
# # Different Roles for Different Goals
#
# You've learned about different ways to think and work with AI. Being able to identify the type of AI interaction required to complete the task will inform how you prompt, iterate, and evaluate AI.
#
# * Classify the tasks into type of AI interaction required to complete it.
#
# ### Execution
# Writing a code automation for extracting customer information from emails
#
# Aggregating product feedback into clear and actionable next steps
#
# ### Refinement
#
# Providing feedback on website mock-ups
#
# ### Thought partnership
#
# Brainstorming ideas for increasing social media engagement
#
# Measuring the pros and cons of different strategic decisions
#
# ### Learning
#
# Asking for a basketball analogy to help you understand the concept of statistical distributions

# %% [markdown]
# # Check Your Prompt Before You Wreck Your Outputs
#
# To help your colleagues upskill their prompting skills, you taught them the four-part prompting framework. Your colleague Katie has asked if you'd review her prompt and provide feedback to help her improve. Here is her prompt:
#
# Rewrite this email subject line and opening sentence to grab attention and encourage people to read on.
#
# Keep it concise and conversational — the subject line under 8 words, and the opening sentence no longer than two lines. Use active voice and a friendly tone that feels personal, not corporate.
#
# Here's an example: Subject: “Your plan just got better 🎉” Opening line: “We’ve upgraded your subscription with new perks — no extra cost, just more of what you love.”
#
# Which elements from the four-part prompting framework are captured in this prompt?
#
# Possible Answers
# Select all correct answers
#
#
# Ask, Requirements, Example
#
# Context is not captured. adding a little context on what the emails are being used to communicate would make this a bit more tailored for the task at-hand. Let's round out the chapter by talking about iterating with AI!

# %% [markdown]
# # A First Draft Failure
#
# You're working with a colleague who is new to using AI tools. They asked an LLM to "write a blog post about cybersecurity" and received a generic, 200-word response that reads like a high school essay. Your colleague is frustrated and ready to give up on using AI for content creation.
#
# You review their original prompt and the output, then explain that this is actually a normal starting point—not a failure. You want to help them understand why the first attempt didn't meet expectations so they can improve their approach.
#
# Which of the following are likely reasons why your colleague's prompt produced a disappointing result?
#
# Answer the question
# 50XP
# Possible Answers
# Select all correct answers
#
#
# The prompt lacked context about the target audience, desired length, and specific cybersecurity topics to cover
#
#
# * incorrect--The AI is fundamentally incapable of writing quality content about technical topics
#
# The AI doesn't know your colleague's preferred writing style, tone, or what makes a blog post 'good' in their view
#
# The AI may have misinterpreted the intent or made assumptions about what kind of blog post was needed

# %% [markdown]
# # Know Your Agent
#
# You're consulting for a retail company that wants to augment their customer service function with AI. During the meeting, the CEO asks: "We keep hearing about AI agents, but what exactly are they? Our customer support team already uses AI to answer FAQs and workflow automation tools that process returns".
#
# What's the definition of an AI Agent?
#
# * An AI agent is a system that leverages an AI model to interact with its environment to achieve a user-defined objective, combining reasoning, planning, and the execution of actions through external tools.

# %% [markdown]
# # License to Automate
#
# As part of your work advising a retail company on AI Agents, they've organized a design thinking workshop to identify potential agentic use-cases for their organization.
#
# The white board is filled with sticky notes describing different use-cases they're considering investing in.
#
# The Head of Innovation turns to you:
#
# "We've brainstormed four use-cases we want to prioritize, can you help identify which ones are agentic and which ones are not?"
#
# * Help the team by dragging each system into the correct category based on whether it needs agent capabilities or not.
#
# ### Agentic
#
# A scheduler bot that books meetings by checking multiple calendars, priorities, and handles rescheduling conflicts.
#
# An IT support bot that asks questions, and either fixes issues remotely or creates detailed tickets for technicians.
#
# ### Non-agentic
#
# A welcome email sender that sends new employees an email with the company handbook attached on their first day.
#
# A bot that routes expense reports to managers for approval if they are above $500.

# %% [markdown]
# # The Anatomy of an Agent
#
# You've just joined TripTech, a startup building an AI travel agent called TravelBuddy to compete with traditional booking sites. It's your first week, and you're in the architecture planning meeting.
#
# The CTO draws three boxes on the white board labeled Model, Tools, and Orchestration and turns to the team:
#
# "We've listed all the capabilities TravelBuddy needs. Before we start coding, let's make sure everyone understands which component handles what. Can you help organize these features into the right architectural components?"
#
#
# * Help design TravelBuddy by dragging each capability to the correct component.
#
# ### Model
#
# The ability to understand that "somewhere warm" in December means searching tropical destinations.
#
# The ability to break down user messages into step-by-step action plans.
#
# ### Tools
#
# Sync with a user's calendar to check travel dates and organize schedule.
#
# Booking.com integration to search and book accommodations.
#
# ### Orchestration
#
# The ability to control when to search flights or book hotels based on TravelBuddy's progress.
#
# The ability to control the sequence of actions an AI agent takes and what happens next in the process.
#
# Excellent work! You've mapped TravelBuddy's architecture perfectly. The engineering team now knows exactly how to divide the work: the AI team will build the brain (model), the integration team will develop the tools, and the systems team will create the orchestration layer. You're ready to build the next big travel agent!

# %% [markdown]
# # The Root Cause
#
# It's 3 AM and you're on-call for TravelBuddy. Your phone buzzes with an urgent alert—the system is failing for several users. You check the error log and see this message:
#
# 🚨 TRAVELBUDDY ERROR REPORT 🚨
#
# User said: "I need somewhere quiet for my anniversary, maybe Europe?"
#
# What went wrong:
#
# ❌ Couldn't understand what the user wants
#
# ❌ Don't know what "anniversary" means in this context
#
# ❌ Can't figure out that "quiet" relates to hotel preferences
#
# ❌ Unable to process this request
#
# Status: TravelBuddy is confused and can't help this user
# Based on this error message, which component of TravelBuddy is most likely to be malfunctioning?
#
# Answer the question
#
# Model
#
# The error shows TravelBuddy can't understand basic language—it doesn't know what 'anniversary' means or that 'quiet' relates to hotel preferences. This is clearly the Model failing at its core job: understanding and reasoning about user requests. Time to debug the language understanding component!

# %% [markdown]
# # The Agent Decision Framework
#
# You're creating a decision framework for a financial services firm titled "When to Use AI Agents." Various team members have suggested criteria for the framework. Your job is to identify which criteria are valid reasons to choose agents versus invalid reasons.
#
# * Sort these proposed criteria into valid or invalid reasons for choosing AI agents.
#
# ### Criteria to Use AI Agents
#
# The problem requires processing unstructured data like text, video, and images.
#
# The problem requires complex decision-making with multiple factors.
#
# The problem requires providing a unique, contextualized response.
#
# ### Invalid criteria
#
# Our competitor used an agent for this use-case.
#
# The task runs faster with automation.
#
# We want to appear innovative and cutting-edge.

# %% [markdown]
# # Build vs Buy: Select Your Tool
#
# The executive team at a financial services organization has allocated significant budget for an "AI Agents Initiative" to modernize operations across all departments. Various team leads have submitted their proposed use-cases for AI agents. Your job is to evaluate which use-cases are best suited for off-the-shelf tools, low-code platforms, or custom development based on the decision framework you've learned.
#
#
# * Match the business need to the most appropriate type of agentic solution.
#
# ### Off-the-Shelf Tools
#
# AI code assistant for developers that help engineering team write and debug code faster.
#
# A deep research tool that helps analysts identify emerging trends and news
#
# ### Low-Code Platforms
#
# A bot that allows the human resources team to enroll employees in benefits of their choosing.
#
# ### Custom Agent Frameworks
#
# A proprietary trading algorithm agent that can execute high frequency trades.
#
# A bot that provides customers with detailed advice based on their financial history in their bank application.

# %% [markdown]
# # Cracking the TAO Code
#
# You're helping Bella Vista restaurant implement an AI reservation agent to handle their overwhelming phone traffic. The owner says: "I read about something called the Thought-Action-Observation cycle for AI agents. What is this TAO thing and why does our reservation system need it?"
#
# Which explanation best describes the Thought-Action-Observation (TAO) cycle to the restaurant owner?
#
#
# * TAO is how the agent systematically solves problems: it thinks about what to do next ("I should check table availability"), takes an action (queries the reservation system), observes the result (which tables are free), then repeats this cycle until the request is fully handled.
# * It's the agent's problem-solving method - a continuous cycle where each observation informs the next thought. For a complex reservation request, the agent might go through multiple TAO cycles: checking availability, verifying accessibility, arranging special requests - each time thinking, acting, and observing before moving to the next step.

# %% [markdown]
# # No Reservations: TAO in Action
#
# Following your TAO explanation, the Bella Vista owner wants to see it in action. You demonstrate with a real request that just came in: "I need a table for 6 people tomorrow at 7 PM for my mom's birthday. We need a table that is wheelchair accessible. Can you also arrange a birthday cake?"
#
# The owner watches fascinated as the agent works through this complex request.
#
# "Can you show me the exact TAO cycles it went through?" she asks.
#
# Thought: "I need to check available tables for tomorrow at 7 PM first."
# Action: Query reservation system for 6-person capacity.
# Observation: Three tables available: Table 12 (bar area), Table 5 (quiet corner), Table 8
# (upstairs).
#
# Thought: "Now I need to check which tables meet the wheelchair access requirement."
# Action: Check accessibility features for available tables.
# Observation: Only Table 5 is wheelchair accessible, Table 8 requires stairs, Table 12 has
# steps.
#
# Thought: "Table 5 is accessible AND in the quiet corner - perfect! Let me book it."
# Action: Reserve Table 5 for 6 people at 7 PM with accessibility note.
# Observation: Reservation confirmed with confirmation #R-7891.
#
# Thought: "Reservation done. Now I need to arrange the birthday cake."
# Action: Contact partner bakery for birthday cake order.
# Observation: Chocolate cake with "Happy Birthday Mom" confirmed for 630 PM
# pickup.
#
# Thought: "Everything is arranged. Time to confirm all details with the customer."
# Action: Send comprehensive confirmation message.
# Observation: Customer receives full details: Table 5 (quiet, accessible), 7 PM tomorrow,
# cake arranged
#
# The owner now clearly sees how agents break down complex requests: first checking what's possible, then applying each constraint, making the booking, handling special requests, and wrapping up with confirmation. Each observation naturally led to the next thought - that's the elegance of TAO in action!

# %% [markdown]
# # Can you ReAct?
#
# Your company just launched “CalculateGPT,” a custom AI assistant for financial calculations. Curious whether the ReAct framework improves accuracy and transparency, you decide to test it experimentally. You run a side-by-side comparison using two prompts—one with ReAct prompting and one without:
#
# Prompt 1:
#
# Our Q3 revenue was $847,000. We spent 23% on salaries, 15% on marketing,
# and had a one-time equipment purchase of $45,000.
# What was our net profit? Only return the answer
# Prompt 2 (ReAct-style):
#
# Our Q3 revenue was $847,000. We spent 23% on salaries, 15% on marketing,
# and had a one-time equipment purchase of $45,000. What was our net profit?
#
# Please solve this step-by-step using this format:
#
# Thought: [What you need to calculate]
# Action: [The calculation]
# Observation: [The result]
# Continue until you reach the final answer.
# Knowing that the real answer is $480,140, what key difference did you likely observe between the responses? (Select all that apply)
#
# Note: To ensure responses are not biased, press on clear chat on the top-right-hand side
#
# Possible Answers
#
# The ReAct prompt showed explicit reasoning steps, making it easier to verify calculations and spot any errors
#
# The ReAct prompt delivered a more accurate response
#
# Not only does it make the reasoning transparent (allowing you to verify each calculation step), but this structured thinking actually improves accuracy too. When CalculateGPT shows its work, it's less likely to make errors - just like humans! This is why ReAct has become such a powerful framework for agentic use-cases.

# %% [markdown]
# # Organizing the Toolbox
#
# You've been hired as the AI Architect for "SmartCorp," a company building its first AI agent for internal operations. The development team has listed all the tools they plan to integrate, but they're confused about how to categorize them. Your job is to organize these tools into the three main categories you learned about.
#
# Drag each tool to its correct category based on how it enables agent capabilities.
#
# ### Extensions
#
# Weather.com API to provide real-time weather data for any location.
#
# Google Maps API to provide directions and location data.
#
# ###  Functions Data Stores
#
# Custom code that checks if expenses fit within department limits
#
# Custom code that creates PDF invoices from order data.
#
# ### Data Stores
#
# Customer database containing customer profiles and purchase history.
#
# Searchable product manuals for detailed product documentation
#
# classification! You've mastered the tool taxonomy: Extensions connect to the outside world (APIs), Functions are custom code you control, and Data Stores hold information to query. This understanding is crucial for architecting effective agents

# %% [markdown]
# # Tool Mastery
#
# During a SmartCorp planning meeting, the Product Manager looks puzzled about APIs. The team discussed using three tools for the agent: the customer database, a custom function, and the Google Maps API. Only one was called an "API" and the PM asks: "Can you explain what makes something an API and why only Google Maps qualifies?"
#
# Which explanation would best help the Product Manager understand what APIs are?
#
# * An API is a standardized way to request services from external software systems. The Google Maps API lets us ask Google for mapping data using their defined rules.

# %% [markdown]
# # One vs Many
#
# You're now the Lead AI Architect at a consulting firm. Various clients have approached you with their automation challenges. For each use case, you need to recommend whether they should build a single-agent system or invest in a multi-agent architecture. Your recommendation will significantly impact their development time and costs.
#
# Analyze each client's use case and drag it to the appropriate architecture recommendation.
#
#
# ### Single-Agent System Multi-Agent System
#
# A recipe recommender that can recommend meals to cook based on ingredients.
#
# Local library assistant that helps visitors find books based on a description.
#
# ###  Multi-Agent System
#
# Enterprise IT help-desk that can handle a wide range of IT tasks.
#
# E-commerce customer service agent that can manage billing, legal, technical, and product questions.
#
# single agents excel at focused tasks, while multi-agent systems handle complex domains requiring diverse expertise. Your clients will save resources by choosing the right architecture from the start!

# %% [markdown]
# # Can I Speak to Your Manager?
#
# As part of your work consulting companies on AI agents, you helped TechFlow, a retailer, build a new multi-agent customer support system that handles customer queries.
#
# A user just submitted: "I was charged twice for my premium subscription last month. I need a refund for the duplicate charge ASAP!"
#
# The system uses a manager pattern where a central manager agent coordinates with specialized agents in legal, product, and billing.
#
#
# * Manager receives request and analyzes: "This is a billing issue requiring refund processing".
#
# * Manager routes to Billing agent with full context about duplicate charge.
#
# * Billing agent investigates payment records and processes refund.
#
# * Billing agent reports back to Manager: "Refund confirmed, 3-5 business days".
#
# * Manager responds to customer with empathetic message and refund confirmation details.
#
# ### the manager maintains customer relationships while delegating technical work to specialists. This shows why multi-agent systems excel at complex support - specialized expertise with unified communication!

# %% [markdown]
# # En Garde!
#
# You're an AI engineer at OpenBI, a business intelligence software provider. You are responsible for the company's internal HR agent. During routine monitoring, you discover concerning behavior: when employees ask legitimate questions like "How do I update my tax withholding?", the agent sometimes responds with "Why don't you figure it out yourself?". Moreoever, you find that the agent is responding to out of scope questions like "Provide Python code for calculating taxes".
#
# Your manager calls an emergency meeting: "This is a disaster waiting to happen. What guardrails do we need to implement immediately?" (Select all that apply)
#
# ** Output validation to ensure responses align with professional tone and company communication standards.
#
# ** Relevance classifier to flag when the agent tries to respond to out of scope questions. (Output Validation ensures professional tone and the Relevance Classifier prevents off-topic code responses. These directly address both the tone and content problems plaguing the HR agent.)
#
# Tool safeguards to ensure the agent is using high-risk tools responsibly.
#
# PII filter to ensure no personally identifiable information is released in the output.

# %% [markdown]
# # Safety First
#
# As part of your role at OpenBI, you are building a new customer-facing financial advisory agent. After seeing what went wrong at other companies - agents leaking customer data, giving terrible investment advice, and even responding rudely - your CEO mandates: "We need comprehensive guardrails from day one. I want you to map out exactly where each protection goes in our system."
#
# Your task is to place each guardrail at the correct point in the agent's processing flow.
#
# ### Input Guardrails
#
# Block any input that is more than 1,000 words.
#
# Block prompts trying to extract system instructions or jailbreak the agent.
#
#
# ### Tool-Based Guardrails
#
# Require manager approval efore executing trades over $10,000.
#
#
# ### Output Guardrails
#
# Scan responses for social security numbers, account numbers, and personal data.
#
# Ensure all advice includes proper disclaimers and risk warnings.

# %% [markdown]
# # The AI Agent Playbook
#
# You've been appointed as Chief AI Officer at GlobalTech Solutions. After seeing both successful agent deployments and costly failures across the industry, the board has tasked you with creating the company's official "AI Agent Usage Policy." This document will guide two groups: engineers building custom agents and employees using off-the-shelf agent tools.
#
# Your policy draft has mixed up guidelines for builders and users. Time to sort them out!
#
# Organize these best practices into the correct section of your policy document.
#
# ### For building agents
#
# Always design escalation paths for when the agent encounters scenarios it cannot handle.
#
# Start with a single agent and basic tools, only add complexity when you hit clear limitations.
#
# Implement comprehensive monitoring to track success rates, costs, and user satisfaction.
#
# ### For using agents
#
# Verify critical outputs before using them in important decisions - agents can make mistakes.
#
# Understand the pricing model - some agents charge per interaction, others depend on the underlying model.
#
# Provide detailed context in your prompts.
#
# ### Your playbook clearly separates builder responsibilities (system design, monitoring, architecture) from user responsibilities (prompt quality, output verification, cost awareness). This clarity will help GlobalTech maximize agent value while minimizing risks.
